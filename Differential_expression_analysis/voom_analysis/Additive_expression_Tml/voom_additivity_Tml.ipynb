# %%
library("limma")
library("edgeR")

# %%
source("/ufrc/soltis/shan158538/TragFL_NewAnalysis/SLURM/rnaseq_plot_funcs.R")

# %%
setwd('/ufrc/soltis/shan158538/TragFL_NewAnalysis/OutPut/DE_analysis/Additive_expression_Tml')

# %%
targets <- readTargets()

# %%
print(targets)
# Out:
#                                 files group description
# 1     both_counts_Tdu_1_2_Tdu_Tpr.csv   Tdu       Tdu_1
# 2     both_counts_Tdu_2_2_Tdu_Tpr.csv   Tdu       Tdu_2
# 3     both_counts_Tdu_3_2_Tdu_Tpr.csv   Tdu       Tdu_3
# 4     both_counts_Tpr_1_2_Tdu_Tpr.csv   Tpr       Tpr_1
# 5     both_counts_Tpr_2_2_Tdu_Tpr.csv   Tpr       Tpr_2
# 6     both_counts_Tpr_3_2_Tdu_Tpr.csv   Tpr       Tpr_3
# 7 both_counts_new_Tml_1_2_tdu_tpr.csv   Tml       Tml_1
# 8 both_counts_new_Tml_2_2_tdu_tpr.csv   Tml       Tml_2
# 9 both_counts_new_Tml_3_2_tdu_tpr.csv   Tml       Tml_3

# %%
d <- readDGE(targets, sep=",")

# %%
print(dim(d))
# Out:
# [1] 11864     9

# %%
colnames(d) <- c("Tdu1","Tdu2","Tdu3","Tpr1","Tpr2","Tpr3","Tml1","Tml2","Tml3")

# %%
printHead(d)
# Out:
# $samples
#                                    files group description lib.size
# Tdu1     both_counts_Tdu_1_2_Tdu_Tpr.csv   Tdu       Tdu_1   976225
# Tdu2     both_counts_Tdu_2_2_Tdu_Tpr.csv   Tdu       Tdu_2  1243376
# Tdu3     both_counts_Tdu_3_2_Tdu_Tpr.csv   Tdu       Tdu_3  1365966
# Tpr1     both_counts_Tpr_1_2_Tdu_Tpr.csv   Tpr       Tpr_1   800814
# Tpr2     both_counts_Tpr_2_2_Tdu_Tpr.csv   Tpr       Tpr_2  1454907
# Tpr3     both_counts_Tpr_3_2_Tdu_Tpr.csv   Tpr       Tpr_3   708250
# Tml1 both_counts_new_Tml_1_2_tdu_tpr.csv   Tml       Tml_1   475528
# Tml2 both_counts_new_Tml_2_2_tdu_tpr.csv   Tml       Tml_2   493618
# Tml3 both_counts_new_Tml_3_2_tdu_tpr.csv   Tml       Tml_3   519307
#      norm.factors
# Tdu1            1
# Tdu2            1
# Tdu3            1
# Tpr1            1
# Tpr2            1
# Tpr3            1
# Tml1            1
# Tml2            1
# Tml3            1
#
# $counts
#                                                       Samples
# Tags                                                   Tdu1 Tdu2 Tdu3 Tpr1 Tpr2
#   Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1    92  109  123  103  173
#   Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5   157  218  281  204  402
#   Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1   36   64   58   21   25
#   Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1     96  140  142  141  200
#   Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3   773 1099  976  751 1281
#                                                       Samples
# Tags                                                   Tpr3 Tml1 Tml2 Tml3
#   Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1    78   71   58   79
#   Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5   205  135  137  111
#   Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1   18   26   20    9
#   Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1    119   71   38   47
#   Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3   700  437  337  388
# 11859 more rows ...

# %%
all_samples = as.matrix(d$counts)
colnames(all_samples) <- d$samples$description
write.csv(all_samples, "all_samples.csv")

# %%
keep <- rowSums(cpm(d) > cpm(10,mean(d$samples$lib.size))[1]) >= 3
d <- d[keep,, keep.lib.sizes=FALSE]

# %% [markdown]
# # ">= 3" means have to meet the condidtion in as least 3 samples. This is because there are 3 replciates per species
# # keep.lib.sizes=FALSE causes the library sizes to be recomputed after the filtering

# %%
print(dim(d))
# Out:
# [1] 8376    9

# %% [markdown]
# # After removing low counts orthologs, there are 8,376 loci left

# %%
pdf("additive_boxplot_log-CPM.pdf")

# %%
boxplot(cpm(d$counts + 1, log=TRUE))
# Out:
# plot without title

# %%
dev.off()
# Out:
# pdf
#   3

# %%
trt = factor(c(1,1,1,2,2,2,3,3,3), labels=c("Tdu","Tpr","Tml"))
design=model.matrix(~0 + trt)

# %%
pdf("additive_voom_plot.pdf")

# %%
voom=voom(d, design, plot=TRUE)
# Out:
# Plot with title “voom: Mean-variance trend”

# %%
dev.off()
# Out:
# pdf
#   3

# %%
write.table(voom$E, "additive_voom_expression_values.txt", sep="\t", quote=F, row.names = TRUE)
fit = lmFit(voom, design)
overall_model <- eBayes(fit)

# %%
pdf("additive_residual_std_dev.pdf")

# %%
plotSA(overall_model)
# Out:
# plot without title

# %%
dev.off()
# Out:
# pdf
#   3

# %%
topTable(overall_model, coef=ncol(design))
top=topTable(overall_model, sort="none", n=Inf, coef=ncol(design))
write.table(top, "additive_DE_overall_model.txt", sep="\t", quote=F, row.names = TRUE)
# Out:
#                                                     logFC    AveExpr  t
# Tpr_TRINITY_DN13584_c4_g1|Tdu_TRINITY_DN21118_c5_g1 10.85594 11.47236 91.92672
# Tpr_TRINITY_DN11525_c2_g3|Tdu_TRINITY_DN17060_c5_g3 11.18860 10.99051 90.50869
# Tpr_TRINITY_DN15098_c1_g6|Tdu_TRINITY_DN22619_c1_g1 14.75585 14.27302 89.42118
# Tpr_TRINITY_DN11928_c4_g3|Tdu_TRINITY_DN20996_c3_g2 11.18697 11.41675 88.35026
# Tpr_TRINITY_DN13339_c0_g1|Tdu_TRINITY_DN21172_c9_g1 12.00410 11.57523 86.76140
# Tpr_TRINITY_DN13270_c4_g1|Tdu_TRINITY_DN23742_c4_g1 10.46540 10.71391 86.57161
# Tpr_TRINITY_DN11540_c1_g1|Tdu_TRINITY_DN14814_c0_g1 10.36201 10.35346 86.04755
# Tpr_TRINITY_DN12100_c1_g5|Tdu_TRINITY_DN21143_c2_g4 10.81203 10.92405 85.45767
# Tpr_TRINITY_DN12153_c0_g2|Tdu_TRINITY_DN17816_c3_g7 11.49095 11.50036 84.73928
# Tpr_TRINITY_DN15350_c0_g5|Tdu_TRINITY_DN16990_c3_g6 15.23507 15.08089 83.64302
#                                                     P.Value      adj.P.Val
# Tpr_TRINITY_DN13584_c4_g1|Tdu_TRINITY_DN21118_c5_g1 1.534169e-16 2.733031e-13
# Tpr_TRINITY_DN11525_c2_g3|Tdu_TRINITY_DN17060_c5_g3 1.804459e-16 2.733031e-13
# Tpr_TRINITY_DN15098_c1_g6|Tdu_TRINITY_DN22619_c1_g1 2.047131e-16 2.733031e-13
# Tpr_TRINITY_DN11928_c4_g3|Tdu_TRINITY_DN20996_c3_g2 2.321459e-16 2.733031e-13
# Tpr_TRINITY_DN13339_c0_g1|Tdu_TRINITY_DN21172_c9_g1 2.805565e-16 2.733031e-13
# Tpr_TRINITY_DN13270_c4_g1|Tdu_TRINITY_DN23742_c4_g1 2.870427e-16 2.733031e-13
# Tpr_TRINITY_DN11540_c1_g1|Tdu_TRINITY_DN14814_c0_g1 3.058219e-16 2.733031e-13
# Tpr_TRINITY_DN12100_c1_g5|Tdu_TRINITY_DN21143_c2_g4 3.285850e-16 2.733031e-13
# Tpr_TRINITY_DN12153_c0_g2|Tdu_TRINITY_DN17816_c3_g7 3.588485e-16 2.733031e-13
# Tpr_TRINITY_DN15350_c0_g5|Tdu_TRINITY_DN16990_c3_g6 4.110822e-16 2.733031e-13
#                                                     B
# Tpr_TRINITY_DN13584_c4_g1|Tdu_TRINITY_DN21118_c5_g1 25.64429
# Tpr_TRINITY_DN11525_c2_g3|Tdu_TRINITY_DN17060_c5_g3 25.58309
# Tpr_TRINITY_DN15098_c1_g6|Tdu_TRINITY_DN22619_c1_g1 25.54822
# Tpr_TRINITY_DN11928_c4_g3|Tdu_TRINITY_DN20996_c3_g2 25.46192
# Tpr_TRINITY_DN13339_c0_g1|Tdu_TRINITY_DN21172_c9_g1 25.39573
# Tpr_TRINITY_DN13270_c4_g1|Tdu_TRINITY_DN23742_c4_g1 25.32392
# Tpr_TRINITY_DN11540_c1_g1|Tdu_TRINITY_DN14814_c0_g1 25.28625
# Tpr_TRINITY_DN12100_c1_g5|Tdu_TRINITY_DN21143_c2_g4 25.27368
# Tpr_TRINITY_DN12153_c0_g2|Tdu_TRINITY_DN17816_c3_g7 25.25582
# Tpr_TRINITY_DN15350_c0_g5|Tdu_TRINITY_DN16990_c3_g6 25.18663

# %%
print(summary(top))
# Out:
#      logFC            AveExpr             t               P.Value
#  Min.   : 0.0283   Min.   : 1.295   Min.   : 0.04116   Min.   :0.0000000
#  1st Qu.: 4.2557   1st Qu.: 4.248   1st Qu.: 9.23832   1st Qu.:0.0000000
#  Median : 5.3585   Median : 5.354   Median :16.41276   Median :0.0000000
#  Mean   : 5.4805   Mean   : 5.513   Mean   :20.14162   Mean   :0.0030327
#  3rd Qu.: 6.5750   3rd Qu.: 6.584   3rd Qu.:27.35604   3rd Qu.:0.0000024
#  Max.   :15.2351   Max.   :15.081   Max.   :91.92672   Max.   :0.9679456
#    adj.P.Val               B
#  Min.   :0.0000000   Min.   :-6.104
#  1st Qu.:0.0000000   1st Qu.: 5.312
#  Median :0.0000000   Median :10.826
#  Mean   :0.0030633   Mean   :10.441
#  3rd Qu.:0.0000032   3rd Qu.:15.821
#  Max.   :0.9679456   Max.   :25.644

# %% [markdown]
# # Comparing Tdu and Tpr, results are relative to Tdu¶

# %%
contrast.matrix = makeContrasts(contrasts=c("trtTpr-trtTdu"), levels=design)
fit2 = contrasts.fit(fit, contrast.matrix)
fit2 = eBayes(fit2)

# %%
topTable(fit2, coef=ncol(contrast.matrix))
top=topTable(fit2, sort="none", n=Inf, coef=ncol(contrast.matrix))
write.table(top, "DE_Tdu_Tpr.txt", sep="\t", quote=F, row.names = TRUE)
# Out:
#                                                     logFC     AveExpr
# Tpr_TRINITY_DN11894_c0_g1|Tdu_TRINITY_DN15151_c0_g1 -3.126070 6.699491
# Tpr_TRINITY_DN10835_c3_g2|Tdu_TRINITY_DN19567_c0_g4  2.583671 7.087423
# Tpr_TRINITY_DN12124_c1_g1|Tdu_TRINITY_DN20551_c2_g1  3.458685 6.814620
# Tpr_TRINITY_DN12160_c1_g3|Tdu_TRINITY_DN16869_c3_g1  2.163245 7.777539
# Tpr_TRINITY_DN10604_c3_g3|Tdu_TRINITY_DN18047_c0_g1 -2.592720 6.712735
# Tpr_TRINITY_DN10582_c3_g4|Tdu_TRINITY_DN19797_c3_g1  3.417881 5.537689
# Tpr_TRINITY_DN11710_c2_g9|Tdu_TRINITY_DN24151_c1_g2 -2.801056 5.839827
# Tpr_TRINITY_DN10778_c2_g1|Tdu_TRINITY_DN24374_c2_g1  2.608463 6.249577
# Tpr_TRINITY_DN12686_c2_g3|Tdu_TRINITY_DN20268_c7_g1  2.907148 5.944225
# Tpr_TRINITY_DN11017_c3_g4|Tdu_TRINITY_DN24232_c0_g1  2.259369 6.859146
#                                                     t         P.Value
# Tpr_TRINITY_DN11894_c0_g1|Tdu_TRINITY_DN15151_c0_g1 -13.05922 8.341400e-08
# Tpr_TRINITY_DN10835_c3_g2|Tdu_TRINITY_DN19567_c0_g4  12.69476 1.103295e-07
# Tpr_TRINITY_DN12124_c1_g1|Tdu_TRINITY_DN20551_c2_g1  11.81284 2.238051e-07
# Tpr_TRINITY_DN12160_c1_g3|Tdu_TRINITY_DN16869_c3_g1  11.55176 2.783957e-07
# Tpr_TRINITY_DN10604_c3_g3|Tdu_TRINITY_DN18047_c0_g1 -11.19033 3.793119e-07
# Tpr_TRINITY_DN10582_c3_g4|Tdu_TRINITY_DN19797_c3_g1  11.25819 3.576791e-07
# Tpr_TRINITY_DN11710_c2_g9|Tdu_TRINITY_DN24151_c1_g2 -10.57100 6.577856e-07
# Tpr_TRINITY_DN10778_c2_g1|Tdu_TRINITY_DN24374_c2_g1  10.44580 7.376575e-07
# Tpr_TRINITY_DN12686_c2_g3|Tdu_TRINITY_DN20268_c7_g1  10.45087 7.342270e-07
# Tpr_TRINITY_DN11017_c3_g4|Tdu_TRINITY_DN24232_c0_g1  10.13933 9.813586e-07
#                                                     adj.P.Val    B
# Tpr_TRINITY_DN11894_c0_g1|Tdu_TRINITY_DN15151_c0_g1 0.0004538737 8.479528
# Tpr_TRINITY_DN10835_c3_g2|Tdu_TRINITY_DN19567_c0_g4 0.0004538737 8.317945
# Tpr_TRINITY_DN12124_c1_g1|Tdu_TRINITY_DN20551_c2_g1 0.0004538737 7.624614
# Tpr_TRINITY_DN12160_c1_g3|Tdu_TRINITY_DN16869_c3_g1 0.0004538737 7.447535
# Tpr_TRINITY_DN10604_c3_g3|Tdu_TRINITY_DN18047_c0_g1 0.0004538737 7.120812
# Tpr_TRINITY_DN10582_c3_g4|Tdu_TRINITY_DN19797_c3_g1 0.0004538737 7.019875
# Tpr_TRINITY_DN11710_c2_g9|Tdu_TRINITY_DN24151_c1_g2 0.0005616926 6.502244
# Tpr_TRINITY_DN10778_c2_g1|Tdu_TRINITY_DN24374_c2_g1 0.0005616926 6.477450
# Tpr_TRINITY_DN12686_c2_g3|Tdu_TRINITY_DN20268_c7_g1 0.0005616926 6.438507
# Tpr_TRINITY_DN11017_c3_g4|Tdu_TRINITY_DN24232_c0_g1 0.0006849883 6.207648

# %% [markdown]
# # Comparing (Tdu+Tpr)/2 and Tml, results are relative to Tml

# %%
contrast.matrix=makeContrasts(contrasts=c("(trtTdu+trtTpr)/2-trtTml"), levels=design)
fit2=contrasts.fit(fit, contrast.matrix)
fit2 <- eBayes(fit2)

# %%
topTable(fit2, coef=ncol(contrast.matrix))
top=topTable(fit2, sort="none", n=Inf, coef=ncol(contrast.matrix))
write.table(top, "DE_additive_Tdu_Tpr-Tml.txt", sep="\t", quote=F, row.names = TRUE)
# Out:
#                                                     logFC     AveExpr
# Tpr_TRINITY_DN15984_c4_g3|Tdu_TRINITY_DN22258_c5_g4  4.145379 8.778665
# Tpr_TRINITY_DN12489_c0_g1|Tdu_TRINITY_DN22258_c5_g2  3.102747 7.565344
# Tpr_TRINITY_DN10855_c3_g7|Tdu_TRINITY_DN23834_c1_g2  2.531862 7.864097
# Tpr_TRINITY_DN11118_c3_g2|Tdu_TRINITY_DN22303_c4_g1  2.271921 8.876137
# Tpr_TRINITY_DN11938_c4_g1|Tdu_TRINITY_DN23777_c2_g1  2.458317 6.970476
# Tpr_TRINITY_DN11700_c2_g3|Tdu_TRINITY_DN18621_c0_g2  2.331139 8.982000
# Tpr_TRINITY_DN11974_c1_g2|Tdu_TRINITY_DN24006_c1_g1 -1.792723 6.626265
# Tpr_TRINITY_DN13839_c4_g1|Tdu_TRINITY_DN24059_c2_g2 -1.652043 7.863845
# Tpr_TRINITY_DN10734_c0_g1|Tdu_TRINITY_DN23311_c1_g1  2.423702 8.004630
# Tpr_TRINITY_DN13966_c1_g1|Tdu_TRINITY_DN21585_c2_g2  2.013008 6.921897
#                                                     t         P.Value
# Tpr_TRINITY_DN15984_c4_g3|Tdu_TRINITY_DN22258_c5_g4 13.410133 6.414054e-08
# Tpr_TRINITY_DN12489_c0_g1|Tdu_TRINITY_DN22258_c5_g2 12.492031 1.292999e-07
# Tpr_TRINITY_DN10855_c3_g7|Tdu_TRINITY_DN23834_c1_g2 10.782992 5.431702e-07
# Tpr_TRINITY_DN11118_c3_g2|Tdu_TRINITY_DN22303_c4_g1  9.974234 1.147917e-06
# Tpr_TRINITY_DN11938_c4_g1|Tdu_TRINITY_DN23777_c2_g1 10.373877 7.882656e-07
# Tpr_TRINITY_DN11700_c2_g3|Tdu_TRINITY_DN18621_c0_g2  9.385585 2.043859e-06
# Tpr_TRINITY_DN11974_c1_g2|Tdu_TRINITY_DN24006_c1_g1 -8.938542 3.231043e-06
# Tpr_TRINITY_DN13839_c4_g1|Tdu_TRINITY_DN24059_c2_g2 -8.265410 6.669507e-06
# Tpr_TRINITY_DN10734_c0_g1|Tdu_TRINITY_DN23311_c1_g1  7.325267 1.984669e-05
# Tpr_TRINITY_DN13966_c1_g1|Tdu_TRINITY_DN21585_c2_g2  7.091343 2.643911e-05
#                                                     adj.P.Val    B
# Tpr_TRINITY_DN15984_c4_g3|Tdu_TRINITY_DN22258_c5_g4 0.0005372411 8.220883
# Tpr_TRINITY_DN12489_c0_g1|Tdu_TRINITY_DN22258_c5_g2 0.0005415081 7.446386
# Tpr_TRINITY_DN10855_c3_g7|Tdu_TRINITY_DN23834_c1_g2 0.0015165312 6.529533
# Tpr_TRINITY_DN11118_c3_g2|Tdu_TRINITY_DN22303_c4_g1 0.0019229910 6.003176
# Tpr_TRINITY_DN11938_c4_g1|Tdu_TRINITY_DN23777_c2_g1 0.0016506282 5.967955
# Tpr_TRINITY_DN11700_c2_g3|Tdu_TRINITY_DN18621_c0_g2 0.0028532274 5.464997
# Tpr_TRINITY_DN11974_c1_g2|Tdu_TRINITY_DN24006_c1_g1 0.0038661738 5.019936
# Tpr_TRINITY_DN13839_c4_g1|Tdu_TRINITY_DN24059_c2_g2 0.0069829734 4.332310
# Tpr_TRINITY_DN10734_c0_g1|Tdu_TRINITY_DN23311_c1_g1 0.0166235902 3.273747
# Tpr_TRINITY_DN13966_c1_g1|Tdu_TRINITY_DN21585_c2_g2 0.0201321832 2.969827

# %%
pdf("additive_MDS_plot.pdf")

# %%
plotMDS(voom, main="MDS plot")
# Out:
# Plot with title “MDS plot”

# %%
dev.off()
# Out:
# pdf
#   3
