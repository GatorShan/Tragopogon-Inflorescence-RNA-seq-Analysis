# %%
library("limma")
library("edgeR")

# %%
source("/ufrc/soltis/shan158538/TragFL_NewAnalysis/SLURM/rnaseq_plot_funcs.R")
# source causes R to accept its input from the named file

# %%
setwd('/ufrc/soltis/shan158538/TragFL_NewAnalysis/OutPut/DE_analysis/Tdu_Tpr_voom_Tml')
# set working directory in R

# %%
targets <- readTargets()
# the default file to be read here is Traget.txt

# %%
print(targets)
# Out:
#                             files group description
# 1 both_counts_Tdu_1_2_Tdu_Tpr.csv   Tdu       Tdu_1
# 2 both_counts_Tdu_2_2_Tdu_Tpr.csv   Tdu       Tdu_2
# 3 both_counts_Tdu_3_2_Tdu_Tpr.csv   Tdu       Tdu_3
# 4 both_counts_Tpr_1_2_Tdu_Tpr.csv   Tpr       Tpr_1
# 5 both_counts_Tpr_2_2_Tdu_Tpr.csv   Tpr       Tpr_2
# 6 both_counts_Tpr_3_2_Tdu_Tpr.csv   Tpr       Tpr_3

# %%
d <- readDGE(targets, sep=",")
# readDGE: Reads and merges a set of text files containing gene expression counts

# %%
print(dim(d))
# dim: Retrieve or set the dimension of an object
# Out:
# [1] 11864     6

# %%
colnames(d) <- c("Tdu_1","Tdu_2","Tdu_3","Tpr_1","Tpr_2","Tpr_3")

# %%
printHead(d)
# Out:
# $samples
#                                 files group description lib.size norm.factors
# Tdu_1 both_counts_Tdu_1_2_Tdu_Tpr.csv   Tdu       Tdu_1   976225            1
# Tdu_2 both_counts_Tdu_2_2_Tdu_Tpr.csv   Tdu       Tdu_2  1243376            1
# Tdu_3 both_counts_Tdu_3_2_Tdu_Tpr.csv   Tdu       Tdu_3  1365966            1
# Tpr_1 both_counts_Tpr_1_2_Tdu_Tpr.csv   Tpr       Tpr_1   800814            1
# Tpr_2 both_counts_Tpr_2_2_Tdu_Tpr.csv   Tpr       Tpr_2  1454907            1
# Tpr_3 both_counts_Tpr_3_2_Tdu_Tpr.csv   Tpr       Tpr_3   708250            1
#
# $counts
#                                                       Samples
# Tags                                                   Tdu_1 Tdu_2 Tdu_3 Tpr_1
#   Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1     92   109   123   103
#   Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5    157   218   281   204
#   Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1    36    64    58    21
#   Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1      96   140   142   141
#   Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3    773  1099   976   751
#                                                       Samples
# Tags                                                   Tpr_2 Tpr_3
#   Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1    173    78
#   Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5    402   205
#   Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1    25    18
#   Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1     200   119
#   Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3   1281   700
# 11859 more rows ...

# %%
keep <- rowSums(cpm(d) > cpm(10,mean(d$samples$lib.size))[1]) >= 3
# rowSums: sum values of Raster objects by row or column
# cpm: Computes counts per million (CPM)
# The $ allows you extract elements by name

# %% [markdown]
# # ">= 3" means have to meet the condidtion in as least 3 samples. This is because there are 3 replciates per species
# # Following the method from [Chen et al., (2016)](https://f1000research.com/articles/5-1438/v2)

# %%
d <- d[keep,, keep.lib.sizes=FALSE]

# %% [markdown]
# # keep.lib.sizes=FALSE causes the library sizes to be recomputed after the filtering

# %%
printHead(d)
# Out:
# $samples
#                                 files group description lib.size norm.factors
# Tdu_1 both_counts_Tdu_1_2_Tdu_Tpr.csv   Tdu       Tdu_1   963881            1
# Tdu_2 both_counts_Tdu_2_2_Tdu_Tpr.csv   Tdu       Tdu_2  1229499            1
# Tdu_3 both_counts_Tdu_3_2_Tdu_Tpr.csv   Tdu       Tdu_3  1349311            1
# Tpr_1 both_counts_Tpr_1_2_Tdu_Tpr.csv   Tpr       Tpr_1   791750            1
# Tpr_2 both_counts_Tpr_2_2_Tdu_Tpr.csv   Tpr       Tpr_2  1438687            1
# Tpr_3 both_counts_Tpr_3_2_Tdu_Tpr.csv   Tpr       Tpr_3   700913            1
#
# $counts
#                                                       Samples
# Tags                                                   Tdu_1 Tdu_2 Tdu_3 Tpr_1
#   Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1     92   109   123   103
#   Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5    157   218   281   204
#   Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1    36    64    58    21
#   Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1      96   140   142   141
#   Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3    773  1099   976   751
#                                                       Samples
# Tags                                                   Tpr_2 Tpr_3
#   Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1    173    78
#   Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5    402   205
#   Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1    25    18
#   Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1     200   119
#   Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3   1281   700
# 8243 more rows ...

# %%
print(dim(d))
# Out:
# [1] 8248    6

# %% [markdown]
# # After removing low counts orthologs, there are 8,248 left

# %%
pdf("boxplot_log-CPM.pdf")
# starts the graphics device driver for producing PDF graphics

# %%
boxplot(cpm(d$counts + 1, log=TRUE))
# boxplot: Produce box-and-whisker plot(s) of the given (grouped) values
# log: character indicating if x or y or both coordinates should be plotted in log scale.
# Out:
# plot without title

# %%
dev.off()
# This function closes the specified plot (by default the current device) and if it is an imguR device, uploads the plots for web hosting
# Out:
# pdf
#   3

# %%
trt = factor(c(1,1,1,2,2,2), labels=c("Tdu","Tpr"))
# factor: The function factor is used to encode a vector as a factor
# lables: an optional character vector of labels for the levels

# %%
printHead(trt)
# Out:
# [1] Tdu Tdu Tdu Tpr Tpr Tpr
# Levels: Tdu Tpr

# %%
design=model.matrix(~0 + trt)
# model.matrix creates a design (or model) matrix, e.g., by expanding factors to a set of dummy variables (depending on the contrasts) and expanding interactions similarly.

# %%
printHead(design)
# Out:
#   trtTdu trtTpr
# 1      1      0
# 2      1      0
# 3      1      0
# 4      0      1
# 5      0      1
# 6      0      1
# attr(,"assign")
# [1] 1 1
# attr(,"contrasts")
# attr(,"contrasts")$trt
# [1] "contr.treatment"

# %%
voom=voom(d, design, plot=TRUE)
# voom: This function is intended to process RNA-Seq or ChIP-Seq data prior to linear modelling in limma.
# The key concern is to estimate the mean-variance relationship in the data, then use this to compute appropriate weights for each observation. Count data almost show non-trivial mean-variance relationships. Raw counts show increasing variance with increasing count size, while log-counts typically show a decreasing mean-variance trend.
# Transform count data to log2-counts per million (logCPM), estimate the mean-variance relationship and use this to compute appropriate observational-level weights. The data are then ready for linear modelling.
# Out:
# Plot with title “voom: Mean-variance trend”

# %%
write.table(voom$E, "voom_expression_values_min10_3rep.txt", sep="\t", quote=F, row.names = TRUE)
# write.table prints its required argument x to a file
# quote: If FALSE, nothing is quoted.

# %%
fit = lmFit(voom, design)
# lmFit: Fit linear model for each gene given a series of arrays

# %%
printHead(fit)
# Out:
# $coefficients
#                                                        trtTdu   trtTpr
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1  6.523545 6.918903
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  7.514999 8.111918
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1 5.475325 4.465863
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1   6.737632 7.324402
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  9.650411 9.883337
# 8243 more rows ...
#
# $stdev.unscaled
#                                                         trtTdu    trtTpr
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1  0.1504733 0.1496182
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  0.1340647 0.1317447
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1 0.1840548 0.2534399
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1   0.1461013 0.1416006
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  0.1216319 0.1220077
# 8243 more rows ...
#
# $sigma
# [1] 0.3246624 0.6138145 0.7801527 0.6253610 0.5850928
# 8243 more elements ...
#
# $df.residual
# [1] 4 4 4 4 4
# 8243 more elements ...
#
# $cov.coefficients
#           trtTdu    trtTpr
# trtTdu 0.3333333 0.0000000
# trtTpr 0.0000000 0.3333333
#
# $pivot
# [1] 1 2
#
# $rank
# [1] 2
#
# $Amean
#  Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1
#                                             6.721505
#  Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5
#                                             7.811180
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1
#                                             5.004526
#   Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1
#                                             7.037046
#  Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3
#                                             9.767741
# 8243 more elements ...
#
# $method
# [1] "ls"
#
# $design
#   trtTdu trtTpr
# 1      1      0
# 2      1      0
# 3      1      0
# 4      0      1
# 5      0      1
# 6      0      1
# attr(,"assign")
# [1] 1 1
# attr(,"contrasts")
# attr(,"contrasts")$trt
# [1] "contr.treatment"

# %%
overall_model <- eBayes(fit)
# eBayes: Empirical Bayes Statistics For Differential Expression
# Given a microarray linear model fit, compute moderated t-statistics, moderated F-statistic, and log-odds of differential expression by empirical Bayes moderation of the standard errors towards a common value.

# %%
printHead(overall_model)
# Out:
# $coefficients
#                                                        trtTdu   trtTpr
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1  6.523545 6.918903
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  7.514999 8.111918
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1 5.475325 4.465863
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1   6.737632 7.324402
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  9.650411 9.883337
# 8243 more rows ...
#
# $stdev.unscaled
#                                                         trtTdu    trtTpr
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1  0.1504733 0.1496182
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  0.1340647 0.1317447
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1 0.1840548 0.2534399
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1   0.1461013 0.1416006
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  0.1216319 0.1220077
# 8243 more rows ...
#
# $sigma
# [1] 0.3246624 0.6138145 0.7801527 0.6253610 0.5850928
# 8243 more elements ...
#
# $df.residual
# [1] 4 4 4 4 4
# 8243 more elements ...
#
# $cov.coefficients
#           trtTdu    trtTpr
# trtTdu 0.3333333 0.0000000
# trtTpr 0.0000000 0.3333333
#
# $pivot
# [1] 1 2
#
# $rank
# [1] 2
#
# $Amean
#  Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1
#                                             6.721505
#  Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5
#                                             7.811180
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1
#                                             5.004526
#   Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1
#                                             7.037046
#  Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3
#                                             9.767741
# 8243 more elements ...
#
# $method
# [1] "ls"
#
# $design
#   trtTdu trtTpr
# 1      1      0
# 2      1      0
# 3      1      0
# 4      0      1
# 5      0      1
# 6      0      1
# attr(,"assign")
# [1] 1 1
# attr(,"contrasts")
# attr(,"contrasts")$trt
# [1] "contr.treatment"
#
#
# $df.prior
# [1] 5.617501
#
# $s2.prior
# [1] 1.004758
#
# $var.prior
# [1] 15.92423 15.92423
#
# $proportion
# [1] 0.01
#
# $s2.post
# [1] 0.6307100 0.7435719 0.8400087 0.7495228 0.7292503
# 8243 more elements ...
#
# $t
#                                                        trtTdu   trtTpr
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1  54.58954 58.22883
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  65.00591 71.40507
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1 32.45792 19.22598
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1   53.26732 59.74678
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  92.90949 94.85888
# 8243 more rows ...
#
# $df.total
# [1] 9.617501 9.617501 9.617501 9.617501 9.617501
# 8243 more elements ...
#
# $p.value
#                                                            trtTdu       trtTpr
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1  2.592021e-13 1.395780e-13
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  4.853170e-14 1.970619e-14
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1 3.749437e-11 5.365480e-09
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1   3.279012e-13 1.090431e-13
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  1.572156e-15 1.287811e-15
# 8243 more rows ...
#
# $lods
#                                                        trtTdu   trtTpr
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1  20.65931 21.13797
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  22.19267 22.88718
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1 16.19720 11.39174
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1   20.53898 21.45633
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  24.80027 24.90701
# 8243 more rows ...
#
# $F
# [1] 3185.3076 4662.2264  711.5775 3203.5428 8815.1899
# 8243 more elements ...
#
# $F.p.value
# [1] 2.696443e-14 4.327324e-15 3.548394e-11 2.623539e-14 2.027444e-16
# 8243 more elements ...

# %%
pdf("residual_std_dev.pdf")
# standard deviation (SD, also represented by the lower case Greek letter sigma σ)

# %%
plotSA(overall_model)
# Out:
# plot without title

# %%
dev.off()
# Out:
# pdf
#   3

# %%
topTable(overall_model, coef=ncol(design))
# topTable: Extract a table of the top-ranked genes from a linear model fit; selecting the top-ranked genes for any given contrast
# Out:
#                                                     logFC    AveExpr  t
# Tpr_TRINITY_DN15350_c0_g5|Tdu_TRINITY_DN16990_c3_g6 14.99818 15.00516 120.3492
# Tpr_TRINITY_DN12194_c4_g1|Tdu_TRINITY_DN24973_c6_g2 12.75459 12.78973 121.0213
# Tpr_TRINITY_DN10371_c4_g2|Tdu_TRINITY_DN22413_c3_g1 13.19983 13.14825 118.8175
# Tpr_TRINITY_DN13224_c2_g2|Tdu_TRINITY_DN21311_c1_g1 11.40224 11.51976 117.6765
# Tpr_TRINITY_DN13159_c0_g2|Tdu_TRINITY_DN18363_c1_g1 11.86656 11.62400 116.4078
# Tpr_TRINITY_DN13584_c4_g1|Tdu_TRINITY_DN21118_c5_g1 11.85058 11.78201 116.1814
# Tpr_TRINITY_DN11928_c4_g3|Tdu_TRINITY_DN20996_c3_g2 11.56988 11.53301 115.4260
# Tpr_TRINITY_DN11525_c2_g3|Tdu_TRINITY_DN17060_c5_g3 10.69755 10.89290 114.6895
# Tpr_TRINITY_DN11314_c4_g8|Tdu_TRINITY_DN17197_c0_g1 11.52005 11.51837 112.4318
# Tpr_TRINITY_DN12100_c1_g5|Tdu_TRINITY_DN21143_c2_g4 11.06418 10.98143 112.6075
#                                                     P.Value      adj.P.Val
# Tpr_TRINITY_DN15350_c0_g5|Tdu_TRINITY_DN16990_c3_g6 1.307698e-16 1.867143e-13
# Tpr_TRINITY_DN12194_c4_g1|Tdu_TRINITY_DN24973_c6_g2 1.239543e-16 1.867143e-13
# Tpr_TRINITY_DN10371_c4_g2|Tdu_TRINITY_DN22413_c3_g1 1.479022e-16 1.867143e-13
# Tpr_TRINITY_DN13224_c2_g2|Tdu_TRINITY_DN21311_c1_g1 1.622757e-16 1.867143e-13
# Tpr_TRINITY_DN13159_c0_g2|Tdu_TRINITY_DN18363_c1_g1 1.800948e-16 1.867143e-13
# Tpr_TRINITY_DN13584_c4_g1|Tdu_TRINITY_DN21118_c5_g1 1.834964e-16 1.867143e-13
# Tpr_TRINITY_DN11928_c4_g3|Tdu_TRINITY_DN20996_c3_g2 1.953689e-16 1.867143e-13
# Tpr_TRINITY_DN11525_c2_g3|Tdu_TRINITY_DN17060_c5_g3 2.077664e-16 1.867143e-13
# Tpr_TRINITY_DN11314_c4_g8|Tdu_TRINITY_DN17197_c0_g1 2.515132e-16 1.867143e-13
# Tpr_TRINITY_DN12100_c1_g5|Tdu_TRINITY_DN21143_c2_g4 2.477673e-16 1.867143e-13
#                                                     B
# Tpr_TRINITY_DN15350_c0_g5|Tdu_TRINITY_DN16990_c3_g6 26.39984
# Tpr_TRINITY_DN12194_c4_g1|Tdu_TRINITY_DN24973_c6_g2 26.35774
# Tpr_TRINITY_DN10371_c4_g2|Tdu_TRINITY_DN22413_c3_g1 26.29118
# Tpr_TRINITY_DN13224_c2_g2|Tdu_TRINITY_DN21311_c1_g1 26.14939
# Tpr_TRINITY_DN13159_c0_g2|Tdu_TRINITY_DN18363_c1_g1 26.12808
# Tpr_TRINITY_DN13584_c4_g1|Tdu_TRINITY_DN21118_c5_g1 26.11784
# Tpr_TRINITY_DN11928_c4_g3|Tdu_TRINITY_DN20996_c3_g2 26.06927
# Tpr_TRINITY_DN11525_c2_g3|Tdu_TRINITY_DN17060_c5_g3 25.97213
# Tpr_TRINITY_DN11314_c4_g8|Tdu_TRINITY_DN17197_c0_g1 25.93856
# Tpr_TRINITY_DN12100_c1_g5|Tdu_TRINITY_DN21143_c2_g4 25.91453

# %%
top=topTable(overall_model, sort="none", n=Inf, coef=ncol(design))
# Toptable output for all probes in original (unsorted) order can be obtained by topTable(fit,sort="none",n=Inf)

# %%
write.table(top, "DE_overall_model_min10_3rep.txt", sep="\t", quote=F, row.names = TRUE)

# %%
print(summary(top))
# logFC: log2-fold-change
# Out:
#      logFC            AveExpr             t              P.Value
#  Min.   :-0.8917   Min.   : 1.297   Min.   : -1.587   Min.   :0.000000
#  1st Qu.: 4.3594   1st Qu.: 4.323   1st Qu.: 15.414   1st Qu.:0.000000
#  Median : 5.4163   Median : 5.406   Median : 25.772   Median :0.000000
#  Mean   : 5.5804   Mean   : 5.582   Mean   : 30.468   Mean   :0.002563
#  3rd Qu.: 6.6834   3rd Qu.: 6.627   3rd Qu.: 41.686   3rd Qu.:0.000000
#  Max.   :14.9982   Max.   :15.005   Max.   :121.021   Max.   :0.959532
#    adj.P.Val               B
#  Min.   :0.0000000   Min.   :-6.395
#  1st Qu.:0.0000000   1st Qu.: 9.352
#  Median :0.0000000   Median :14.114
#  Mean   :0.0025695   Mean   :13.553
#  3rd Qu.:0.0000001   3rd Qu.:18.459
#  Max.   :0.9595324   Max.   :26.400

# %%
contrast.matrix = makeContrasts(contrasts=c("trtTdu-trtTpr"), levels=design)
# makeContrasts: Construct the contrast matrix corresponding to specified contrasts of a set of parameters

# %%
fit2 = contrasts.fit(fit, contrast.matrix)
# contrasts.fit: Given a linear model fit to microarray data, compute estimated coefficients and standard errors for a given set of contrasts.

# %%
fit2 = eBayes(fit2)

# %%
topTable(fit2, coef=ncol(contrast.matrix))
top=topTable(fit2, sort="none", n=Inf, coef=ncol(contrast.matrix))
write.table(top, "DE_Tdu_Tpr_min10_3rep.txt", sep="\t", quote=F, row.names = TRUE)
# Out:
#                                                     logFC     AveExpr
# Tpr_TRINITY_DN10564_c0_g1|Tdu_TRINITY_DN16653_c0_g1  5.124859 8.203873
# Tpr_TRINITY_DN12451_c1_g4|Tdu_TRINITY_DN22402_c2_g3 -3.301126 8.579217
# Tpr_TRINITY_DN12160_c1_g3|Tdu_TRINITY_DN16869_c3_g1 -2.161163 7.594352
# Tpr_TRINITY_DN10137_c4_g1|Tdu_TRINITY_DN22038_c0_g4 -2.930415 7.224888
# Tpr_TRINITY_DN10835_c3_g2|Tdu_TRINITY_DN19567_c0_g4 -2.582995 6.923468
# Tpr_TRINITY_DN14835_c1_g1|Tdu_TRINITY_DN21687_c1_g1  2.654638 6.671381
# Tpr_TRINITY_DN11894_c0_g1|Tdu_TRINITY_DN15151_c0_g1  3.136986 6.429151
# Tpr_TRINITY_DN11017_c3_g4|Tdu_TRINITY_DN24232_c0_g1 -2.257986 6.941019
# Tpr_TRINITY_DN10604_c3_g3|Tdu_TRINITY_DN18047_c0_g1  2.596353 6.663675
# Tpr_TRINITY_DN14734_c0_g1|Tdu_TRINITY_DN24906_c5_g1  1.901906 9.039630
#                                                     t         P.Value
# Tpr_TRINITY_DN10564_c0_g1|Tdu_TRINITY_DN16653_c0_g1  19.40735 4.912383e-09
# Tpr_TRINITY_DN12451_c1_g4|Tdu_TRINITY_DN22402_c2_g3 -17.37553 1.385067e-08
# Tpr_TRINITY_DN12160_c1_g3|Tdu_TRINITY_DN16869_c3_g1 -13.77176 1.196104e-07
# Tpr_TRINITY_DN10137_c4_g1|Tdu_TRINITY_DN22038_c0_g4 -13.50671 1.429848e-07
# Tpr_TRINITY_DN10835_c3_g2|Tdu_TRINITY_DN19567_c0_g4 -13.33850 1.604009e-07
# Tpr_TRINITY_DN14835_c1_g1|Tdu_TRINITY_DN21687_c1_g1  13.22967 1.729054e-07
# Tpr_TRINITY_DN11894_c0_g1|Tdu_TRINITY_DN15151_c0_g1  13.14236 1.837128e-07
# Tpr_TRINITY_DN11017_c3_g4|Tdu_TRINITY_DN24232_c0_g1 -13.08029 1.918470e-07
# Tpr_TRINITY_DN10604_c3_g3|Tdu_TRINITY_DN18047_c0_g1  12.96852 2.075099e-07
# Tpr_TRINITY_DN14734_c0_g1|Tdu_TRINITY_DN24906_c5_g1  12.40468 3.112589e-07
#                                                     adj.P.Val    B
# Tpr_TRINITY_DN10564_c0_g1|Tdu_TRINITY_DN16653_c0_g1 4.051733e-05 11.353520
# Tpr_TRINITY_DN12451_c1_g4|Tdu_TRINITY_DN22402_c2_g3 5.712015e-05 10.480281
# Tpr_TRINITY_DN12160_c1_g3|Tdu_TRINITY_DN16869_c3_g1 1.217196e-04  8.341796
# Tpr_TRINITY_DN10137_c4_g1|Tdu_TRINITY_DN22038_c0_g4 1.217196e-04  8.171281
# Tpr_TRINITY_DN10835_c3_g2|Tdu_TRINITY_DN19567_c0_g4 1.217196e-04  8.057938
# Tpr_TRINITY_DN14835_c1_g1|Tdu_TRINITY_DN21687_c1_g1 1.217196e-04  7.979006
# Tpr_TRINITY_DN11894_c0_g1|Tdu_TRINITY_DN15151_c0_g1 1.217196e-04  7.900667
# Tpr_TRINITY_DN11017_c3_g4|Tdu_TRINITY_DN24232_c0_g1 1.217196e-04  7.878619
# Tpr_TRINITY_DN10604_c3_g3|Tdu_TRINITY_DN18047_c0_g1 1.222530e-04  7.801064
# Tpr_TRINITY_DN14734_c0_g1|Tdu_TRINITY_DN24906_c5_g1 1.618986e-04  7.336555
