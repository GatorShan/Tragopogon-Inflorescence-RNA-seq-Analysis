# %%
library(tidyverse)
library(RColorBrewer)
library(DESeq2)
library(pheatmap)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which, which.max, which.min
#
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# Loading required package: IRanges
#
#
# Attaching package: ‘IRanges’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:purrr’:
#
#     reduce
#
#
# Loading required package: GenomicRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: SummarizedExperiment
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: DelayedArray
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
# Loading required package: BiocParallel
#
#
# Attaching package: ‘DelayedArray’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colMaxs, colMins, colRanges, rowMaxs, rowMins, rowRanges
#
#
# The following object is masked from ‘package:purrr’:
#
#     simplify
#
#
# The following objects are masked from ‘package:base’:
#
#     aperm, apply, rowsum

# %%
setwd('/ufrc/soltis/shan158538/TragFL_NewAnalysis/OutPut/DE_analysis/Additive_expression_Tml')

# %%
## Loading data
data <- read.table("DESeq2_count_matrix_Tml_additive.csv", sep=",",header = T,row.names=1)
meta <- read.csv("DESeq2_Tml_additive_sample_annotation.tsv", sep = "\t", row.names="sample")
## first column is row names: row.names = 1

# %%
head(data)
# Out:
#                                                      Tdu_1 Tdu_2 Tdu_3 Tdu_4
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1   92    109  123   106
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  157    218  281   177
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  36     64   58    43
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1    96    140  142    80
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  773   1099  976   809
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   50     46   72    28
#                                                      Tdu_5 Tdu_6 Tpr_1 Tpr_2
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1   116  121   103    173
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5   169  238   204    402
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1   36   47    21     25
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1    126  108   141    200
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  1113  918   751   1281
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3    48   39    35    118
#                                                      Tpr_3 Tml_1 Tml_2 Tml_3
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1   78    71    58    79
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  205   135   137   111
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  18    26    20     9
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1   119    71    38    47
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  700   437   337   388
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   55     7    49    58

# %% [markdown]
# ## 1. Normalization and quality control

# %%
## match the metadata and counts data
all(colnames(data) %in% rownames(meta))
# Out:
# [1] TRUE

# %%
## Creat DESeq2Dataset object
dds <- DESeqDataSetFromMatrix(countData = data, colData = meta, design = ~ species)
## generate size factors
## By assigning the results back to the dds object we are filling in the slots of the DESeqDataSet object with the appropriate info
dds <- estimateSizeFactors(dds)

# %%
head(counts(dds, normalized=TRUE))
# Out:
#                                                      Tdu_1     Tdu_2
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1   77.87678  75.08850
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  132.89842 150.17700
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  30.47352  44.08866
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1    81.26273  96.44395
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  654.33426 757.08498
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   42.32434  31.68873
#                                                      Tdu_3     Tdu_4
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1   73.07476 101.54634
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  166.94315 169.56323
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  34.45802  41.19333
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1    84.36273  76.63875
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  579.84525 775.00935
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   42.77547  26.82356
#                                                      Tdu_5     Tdu_6
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1   83.23534 105.00058
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  121.26529 206.53007
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  25.83166  40.78535
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1    90.41081  93.71953
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  798.62878 796.61599
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   34.44221  33.84316
#                                                      Tpr_1     Tpr_2
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1  110.54424 100.39681
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  218.94199 233.29201
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  22.53815  14.50821
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1   151.32755 116.06568
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  806.00704 743.40067
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   37.56358  68.47875
#                                                      Tpr_3     Tml_1
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1   91.08506 148.09348
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  239.39022 281.58620
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  21.01963  54.23142
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1   138.96311 148.09348
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  817.43003 911.50496
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   64.22665  14.60077
#                                                      Tml_2     Tml_3
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1   91.13359 125.29772
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  215.26382 176.05123
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  31.42537  14.27442
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1    59.70821  74.54421
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  529.51756 615.38627
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   76.99217  91.99073

# %%
## write out the matrix of normalized reads count
Normalized_reads_counts = counts(dds, normalized=TRUE)
write.table(Normalized_reads_counts, file="normalized_counts.txt", sep="\t", quote=F, col.names=NA)

# %%
## Transform normalized counts using the rlog transformation
## The rlog transformation of the normalized counts is only necessary for these visualization methods during this quality assessment
## The blind=TRUE argument results in a transformation unbiased to sample condition information
rld <- rlog(dds, blind=TRUE)

# %%
## Plot PCA
plotPCA(rld, intgroup="species") + geom_text(aes(label=name),vjust=2)
# Out:
# plot without title

# %%
## Hierarchical clustering
## Extract the rlog matrix from the object
rld_mat <- assay(rld)
## Compute pairwise correlation values
rld_cor <- cor(rld_mat)
## Plot heatmap
pheatmap(rld_cor)
# Out:
# plot without title

# %% [markdown]
# ### Based on quality control analysis, **Tml_1 looks like a outlier**, and therefore was removed before performing downstream analysis

# %% [markdown]
# ## 2. Remove Tml_1 and perform normalization and quality control again

# %%
## Loading data
data_new <- data[c("Tdu_1", "Tdu_2", "Tdu_3", "Tdu_4", "Tdu_5", "Tdu_6", "Tpr_1", "Tpr_2", "Tpr_3", "Tml_2", "Tml_3")]
meta_new <- read.csv("DESeq2_Tml_additive_sample_annotation_new.tsv", sep = "\t", row.names="sample")

# %%
head(data_new)
# Out:
#                                                      Tdu_1 Tdu_2 Tdu_3 Tdu_4
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1   92    109  123   106
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  157    218  281   177
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  36     64   58    43
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1    96    140  142    80
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  773   1099  976   809
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   50     46   72    28
#                                                      Tdu_5 Tdu_6 Tpr_1 Tpr_2
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1   116  121   103    173
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5   169  238   204    402
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1   36   47    21     25
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1    126  108   141    200
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  1113  918   751   1281
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3    48   39    35    118
#                                                      Tpr_3 Tml_2 Tml_3
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1   78    58    79
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  205   137   111
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  18    20     9
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1   119    38    47
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  700   337   388
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   55    49    58

# %%
## match the metadata and counts data
all(colnames(data_new) %in% rownames(meta_new))
# Out:
# [1] TRUE

# %%
## Creat DESeq2Dataset object
dds_new <- DESeqDataSetFromMatrix(countData = data_new, colData = meta_new, design = ~ species)
## generate size factors
## By assigning the results back to the dds object we are filling in the slots of the DESeqDataSet object with the appropriate info
dds_new <- estimateSizeFactors(dds_new)

# %%
head(counts(dds_new, normalized=TRUE))
# Out:
#                                                      Tdu_1     Tdu_2
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1   83.36933  81.12413
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  142.27157 162.24826
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  32.62278  47.63252
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1    86.99408 104.19613
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  700.48359 817.93961
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   45.30942  34.23587
#                                                      Tdu_3     Tdu_4
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1   78.53594 109.34753
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  179.41950 182.58975
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  37.03321  44.35796
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1    90.66750  82.52644
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  623.17947 834.54862
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   45.97226  28.88425
#                                                      Tdu_5     Tdu_6
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1   89.53791 113.09218
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  130.44748 222.44577
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  27.78763  43.92837
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1    97.25670 100.94178
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  859.10083 858.00513
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   37.05017  36.45120
#                                                      Tpr_1     Tpr_2
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1  119.22526 107.93476
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  236.13546 250.80795
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  24.30806  15.59751
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1   163.21128 124.78007
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  869.30262 799.21637
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   40.51344  73.62024
#                                                      Tpr_3     Tml_2
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1   98.09236  96.82991
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  257.80685 228.71893
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  22.63670  33.38962
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1   149.65373  63.44029
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  880.31607 562.61517
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   69.16769  81.80458
#                                                      Tml_3
# Tpr_TRINITY_DN11257_c2_g1|Tdu_TRINITY_DN16696_c0_g1  132.87579
# Tpr_TRINITY_DN10844_c2_g7|Tdu_TRINITY_DN25328_c2_g5  186.69889
# Tpr_TRINITY_DN15383_c4_g16|Tdu_TRINITY_DN14160_c0_g1  15.13775
# Tpr_TRINITY_DN1451_c0_g1|Tdu_TRINITY_DN16990_c3_g1    79.05268
# Tpr_TRINITY_DN10853_c1_g4|Tdu_TRINITY_DN21860_c3_g3  652.60513
# Tpr_TRINITY_DN12798_c2_g2|Tdu_TRINITY_DN24179_c2_g3   97.55438

# %%
## write out the matrix of normalized reads count
Normalized_reads_counts_new = counts(dds_new, normalized=TRUE)
write.table(Normalized_reads_counts_new, file="normalized_counts.txt", sep="\t", quote=F, col.names=NA)

## Transform normalized counts using the rlog transformation
## The rlog transformation of the normalized counts is only necessary for these visualization methods during this quality assessment
## The blind=TRUE argument results in a transformation unbiased to sample condition information
rld_new <- rlog(dds_new, blind=TRUE)

## Plot PCA
plotPCA(rld_new, intgroup="species") + geom_text(aes(label=name),vjust=2)
# Out:
# plot without title

# %%
## Hierarchical clustering
## Extract the rlog matrix from the object
rld_mat_new <- assay(rld_new)
## Compute pairwise correlation values
rld_cor_new <- cor(rld_mat_new)
## Plot heatmap
pheatmap(rld_cor_new)
# Out:
# plot without title

# %% [markdown]
# ## 3. Now, Let's perform additive expression analysis

# %%
## log2 fold change shrinkage will NOT be performed
## But this will generate the proper resultsNames(dds_new) results, which will be used for comparing MPV to polyploid
## No shrinkage won't affect the number of DE genes identified

dds_new <- DESeq(dds_new, betaPrior = TRUE)
# Out:
# using pre-existing size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing

# %%
plotDispEsts(dds_new)
# Out:
# plot without title

# %% [markdown]
# ### This is a good plot to examine to ensure your data is a good fit for the DESeq2 model. You expect your data to generally scatter around the curve, with the dispersion decreasing with increasing mean expression levels

# %%
resultsNames(dds_new)
# Out:
# [1] "Intercept"  "speciesTdu" "speciesTml" "speciesTpr"

# %%
## Contrast MPV and polyploid; following the method from https://support.bioconductor.org/p/69104/
## cutoff of adjusted p-value (FDR) is set as 0.05
## I think MPV is the baseline for logFC
res_additive_analysis <- results(dds_new, contrast=list("speciesTml", c("speciesTdu","speciesTpr")), listValues=c(1, -1/2), alpha = 0.05)

# %%
plotMA(res_additive_analysis, ylim=c(-2,2))
# Out:
# Plot with title “”

# %%
summary(res_additive_analysis)
# Out:
# out of 11680 with nonzero total read count
# adjusted p-value < 0.05
# LFC > 0 (up)       : 492, 4.2%
# LFC < 0 (down)     : 515, 4.4%
# outliers [1]       : 10, 0.086%
# low counts [2]     : 2714, 23%
# (mean count < 5)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results

# %%
## Write out output files for additive analysis
non_additive_loci <- subset(res_additive_analysis, padj < 0.05)
write.table(non_additive_loci, "DESeq2_Tml_nonAdditive_loci.txt", sep="\t", quote=F, row.names = TRUE)

additive_loci <- subset(res_additive_analysis, padj >= 0.05)
write.table(additive_loci, "DESeq2_Tml_Additive_loci.txt", sep="\t", quote=F, row.names = TRUE)

# %%
## Diplid DE analysis between Tdu and Tpr
## Tpr is the baseline
res_diploid_DE <- results(dds_new, contrast=c("species", "Tdu", "Tpr"), alpha=0.05)

# %%
plotMA(res_diploid_DE, ylim=c(-2,2))
# Out:
# Plot with title “”

# %%
summary(res_diploid_DE)
# Out:
# out of 11680 with nonzero total read count
# adjusted p-value < 0.05
# LFC > 0 (up)       : 959, 8.2%
# LFC < 0 (down)     : 985, 8.4%
# outliers [1]       : 10, 0.086%
# low counts [2]     : 905, 7.7%
# (mean count < 1)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results

# %%
## Write out DE and non_DE loci
DE_loci <- subset(res_diploid_DE, padj < 0.05)
write.table(DE_loci, "DESeq2_DE_loci.txt", sep="\t", quote=F, row.names = TRUE)

non_DE_loci <- subset(res_diploid_DE, padj >= 0.05)
write.table(non_DE_loci, "DESeq2_noneDE_loci.txt", sep="\t", quote=F, row.names = TRUE)
